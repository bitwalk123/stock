# %%
import unicodedata
import pandas as pd

# %%
tse = "https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls"
df = pd.read_excel(tse)
df
# Out:
#             日付   コード                                   銘柄名       市場・商品区分  \
# 0     20250131  1301                                    極洋    プライム（内国株式）
# 1     20250131  1305                ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）       ETF・ETN
# 2     20250131  1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信       ETF・ETN
# 3     20250131  1308                     上場インデックスファンドＴＯＰＩＸ       ETF・ETN
# 4     20250131  1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信       ETF・ETN
# ...        ...   ...                                   ...           ...
# 4405  20250131  9991                                  ジェコス    プライム（内国株式）
# 4406  20250131  9993                                  ヤマザワ  スタンダード（内国株式）
# 4407  20250131  9994                                   やまや  スタンダード（内国株式）
# 4408  20250131  9996                                 サトー商会  スタンダード（内国株式）
# 4409  20250131  9997                                  ベルーナ    プライム（内国株式）
#
#      33業種コード  33業種区分 17業種コード 17業種区分 規模コード           規模区分
# 0         50  水産・農林業       1     食品     7  TOPIX Small 2
# 1          -       -       -      -     -              -
# 2          -       -       -      -     -              -
# 3          -       -       -      -     -              -
# 4          -       -       -      -     -              -
# ...      ...     ...     ...    ...   ...            ...
# 4405    6050     卸売業      13  商社・卸売     7  TOPIX Small 2
# 4406    6100     小売業      14     小売     -              -
# 4407    6100     小売業      14     小売     -              -
# 4408    6050     卸売業      13  商社・卸売     -              -
# 4409    6100     小売業      14     小売     6  TOPIX Small 1
#
# [4410 rows x 10 columns]

# %%
df['銘柄名'] = [unicodedata.normalize('NFKC', s) for s in df['銘柄名']]
df
# Out:
#             日付   コード                                   銘柄名       市場・商品区分  \
# 0     20250131  1301                                    極洋    プライム（内国株式）
# 1     20250131  1305                iFreeETF TOPIX(年1回決算型)       ETF・ETN
# 2     20250131  1306               NEXT FUNDS TOPIX連動型上場投信       ETF・ETN
# 3     20250131  1308                     上場インデックスファンドTOPIX       ETF・ETN
# 4     20250131  1309  NEXT FUNDS ChinaAMC・中国株式・上証50連動型上場投信       ETF・ETN
# ...        ...   ...                                   ...           ...
# 4405  20250131  9991                                  ジェコス    プライム（内国株式）
# 4406  20250131  9993                                  ヤマザワ  スタンダード（内国株式）
# 4407  20250131  9994                                   やまや  スタンダード（内国株式）
# 4408  20250131  9996                                 サトー商会  スタンダード（内国株式）
# 4409  20250131  9997                                  ベルーナ    プライム（内国株式）
#
#      33業種コード  33業種区分 17業種コード 17業種区分 規模コード           規模区分
# 0         50  水産・農林業       1     食品     7  TOPIX Small 2
# 1          -       -       -      -     -              -
# 2          -       -       -      -     -              -
# 3          -       -       -      -     -              -
# 4          -       -       -      -     -              -
# ...      ...     ...     ...    ...   ...            ...
# 4405    6050     卸売業      13  商社・卸売     7  TOPIX Small 2
# 4406    6100     小売業      14     小売     -              -
# 4407    6100     小売業      14     小売     -              -
# 4408    6050     卸売業      13  商社・卸売     -              -
# 4409    6100     小売業      14     小売     6  TOPIX Small 1
#
# [4410 rows x 10 columns]
