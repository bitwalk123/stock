# %% [markdown]
# # Firefly 日足

# %%
import sys

path_up = ".."
if not path_up in sys.path:
    sys.path.append(path_up)

# %%
import datetime

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pingouin as pg
import seaborn as sns
import yfinance as yf

from funcs.technical import psar

# %%
symbol = "FLY"
ticker = yf.Ticker(symbol)

# %%
# 日足で過去 2 年分のデータを取得
df = ticker.history(period="1y", interval="1d")
df
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2025-08-07 00:00:00-04:00  70.000000  73.800003  60.029999  60.349998
# 2025-08-08 00:00:00-04:00  54.845001  57.070000  49.110001  50.169998
# 2025-08-11 00:00:00-04:00  49.509998  54.950001  49.500000  53.619999
# 2025-08-12 00:00:00-04:00  53.776001  55.000000  51.340000  51.465000
# 2025-08-13 00:00:00-04:00  51.119999  53.599998  50.599998  50.750000
# ...                              ...        ...        ...        ...
# 2026-04-10 00:00:00-04:00  37.424999  39.750000  36.150002  37.540001
# 2026-04-13 00:00:00-04:00  36.709999  39.630001  36.700001  38.799999
# 2026-04-14 00:00:00-04:00  40.404999  40.990002  34.080002  36.610001
# 2026-04-15 00:00:00-04:00  36.560001  37.689999  35.060001  37.619999
# 2026-04-16 00:00:00-04:00  38.040001  44.319199  37.080002  44.169998
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-08-07 00:00:00-04:00  30556600        0.0           0.0
# 2025-08-08 00:00:00-04:00   8576200        0.0           0.0
# 2025-08-11 00:00:00-04:00   3410100        0.0           0.0
# 2025-08-12 00:00:00-04:00   1799000        0.0           0.0
# 2025-08-13 00:00:00-04:00   3419300        0.0           0.0
# ...                             ...        ...           ...
# 2026-04-10 00:00:00-04:00   6902100        0.0           0.0
# 2026-04-13 00:00:00-04:00   5499500        0.0           0.0
# 2026-04-14 00:00:00-04:00   9972800        0.0           0.0
# 2026-04-15 00:00:00-04:00   5025200        0.0           0.0
# 2026-04-16 00:00:00-04:00   9088996        0.0           0.0
#
# [174 rows x 7 columns]

# %%
dt = df.tail(1).index[0]
date_str = f"{dt.month:02d}{dt.day:02d}"
date_str
# Out:
# '0416'

# %% [markdown]
# ### Matplotlib の設定

# %%
FONT_PATH = "../fonts/RictyDiminished-Regular.ttf"
fm.fontManager.addfont(FONT_PATH)

# FontPropertiesオブジェクト生成（名前の取得のため）
font_prop = fm.FontProperties(fname=FONT_PATH)
font_prop.get_name()

plt.rcParams["font.family"] = font_prop.get_name()
plt.rcParams["font.size"] = 11

# %% [markdown]
# ## 日足

# %%
fig, ax = plt.subplots(figsize=(6.8, 3))

mpf.plot(
    df,
    type="candle",
    style="default",
    datetime_format="%m/%d",
    xrotation=0,
    update_width_config=dict(candle_linewidth=0.75),
    ax=ax,
)
ax.grid()

try:
    ax.set_title(f"Daily chart for {ticker.info["longName"]} ({symbol})")
except KeyError:
    ax.set_title(f"Daily chart for {symbol}")

plt.tight_layout()
plt.savefig(f"{date_str}_daily_chart_{symbol}.png")
plt.show()
