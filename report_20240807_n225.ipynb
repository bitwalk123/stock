# %%
import datetime as dt
import mplfinance as mpf
import pandas as pd
import yfinance as yf
import wget

# %%
ticker_n225 = yf.Ticker('^N225')
df = ticker_n225.history(period='1mo')
df
# Out:
#                                    Open          High           Low  \
# Date
# 2024-07-08 00:00:00+09:00  40863.140625  41112.238281  40780.699219
# 2024-07-09 00:00:00+09:00  40953.410156  41769.351562  40942.441406
# 2024-07-10 00:00:00+09:00  41444.328125  41889.160156  41430.378906
# 2024-07-11 00:00:00+09:00  42343.718750  42426.769531  42102.460938
# 2024-07-12 00:00:00+09:00  41668.859375  41754.761719  41188.289062
# 2024-07-16 00:00:00+09:00  41366.789062  41520.070312  41220.648438
# 2024-07-17 00:00:00+09:00  41416.179688  41466.449219  41054.718750
# 2024-07-18 00:00:00+09:00  40521.710938  40587.628906  40104.218750
# 2024-07-19 00:00:00+09:00  39965.910156  40212.898438  39824.578125
# 2024-07-22 00:00:00+09:00  39947.949219  39973.199219  39519.390625
# 2024-07-23 00:00:00+09:00  39864.089844  39927.890625  39519.910156
# 2024-07-24 00:00:00+09:00  39336.738281  39643.269531  39096.500000
# 2024-07-25 00:00:00+09:00  38524.199219  38557.789062  37825.578125
# 2024-07-26 00:00:00+09:00  37792.871094  38105.960938  37611.191406
# 2024-07-29 00:00:00+09:00  38139.121094  38719.699219  38010.011719
# 2024-07-30 00:00:00+09:00  38241.351562  38531.160156  38076.699219
# 2024-07-31 00:00:00+09:00  38140.769531  39188.371094  37954.378906
# 2024-08-01 00:00:00+09:00  38781.558594  38781.558594  37737.878906
# 2024-08-02 00:00:00+09:00  37444.171875  37471.519531  35880.148438
# 2024-08-05 00:00:00+09:00  35249.359375  35301.179688  31156.119141
# 2024-08-06 00:00:00+09:00  32077.330078  34911.800781  32077.330078
#
#                                   Close     Volume  Dividends  Stock Splits
# Date
# 2024-07-08 00:00:00+09:00  40780.699219  113000000        0.0           0.0
# 2024-07-09 00:00:00+09:00  41580.171875  118200000        0.0           0.0
# 2024-07-10 00:00:00+09:00  41831.988281  134400000        0.0           0.0
# 2024-07-11 00:00:00+09:00  42224.019531  123000000        0.0           0.0
# 2024-07-12 00:00:00+09:00  41190.679688  130400000        0.0           0.0
# 2024-07-16 00:00:00+09:00  41275.078125  100800000        0.0           0.0
# 2024-07-17 00:00:00+09:00  41097.691406  109900000        0.0           0.0
# 2024-07-18 00:00:00+09:00  40126.351562  117600000        0.0           0.0
# 2024-07-19 00:00:00+09:00  40063.789062   99800000        0.0           0.0
# 2024-07-22 00:00:00+09:00  39599.000000   82700000        0.0           0.0
# 2024-07-23 00:00:00+09:00  39594.390625   88300000        0.0           0.0
# 2024-07-24 00:00:00+09:00  39154.851562  110300000        0.0           0.0
# 2024-07-25 00:00:00+09:00  37869.511719  143000000        0.0           0.0
# 2024-07-26 00:00:00+09:00  37667.410156  124000000        0.0           0.0
# 2024-07-29 00:00:00+09:00  38468.628906  107300000        0.0           0.0
# 2024-07-30 00:00:00+09:00  38525.949219  109700000        0.0           0.0
# 2024-07-31 00:00:00+09:00  39101.820312  146400000        0.0           0.0
# 2024-08-01 00:00:00+09:00  38126.328125  178800000        0.0           0.0
# 2024-08-02 00:00:00+09:00  35909.699219  204300000        0.0           0.0
# 2024-08-05 00:00:00+09:00  31458.419922  285600000        0.0           0.0
# 2024-08-06 00:00:00+09:00  34675.460938          0        0.0           0.0

# %%
mpf.plot(df, type='candle', style='yahoo', title='Nikkei 225')

# %%
ticker_n225.history_metadata
# Out:
# {'currency': 'JPY',
#  'symbol': '^N225',
#  'exchangeName': 'OSA',
#  'fullExchangeName': 'Osaka',
#  'instrumentType': 'INDEX',
#  'firstTradeDate': -157420800,
#  'regularMarketTime': 1722924902,
#  'hasPrePostMarketData': False,
#  'gmtoffset': 32400,
#  'timezone': 'JST',
#  'exchangeTimezoneName': 'Asia/Tokyo',
#  'regularMarketPrice': 34675.46,
#  'fiftyTwoWeekHigh': 34911.8,
#  'fiftyTwoWeekLow': 32077.33,
#  'regularMarketDayHigh': 34911.8,
#  'regularMarketDayLow': 32077.33,
#  'regularMarketVolume': 0,
#  'chartPreviousClose': 40912.37,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'JST',
#    'start': 1722988800,
#    'end': 1722988800,
#    'gmtoffset': 32400},
#   'regular': {'timezone': 'JST',
#    'start': 1722988800,
#    'end': 1723010400,
#    'gmtoffset': 32400},
#   'post': {'timezone': 'JST',
#    'start': 1723010400,
#    'end': 1723010400,
#    'gmtoffset': 32400}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
start = '2024-08-05'
end = '2024-08-06'
df_n225 = ticker_n225.history(start=start, end=end)
df_n225
# Out:
#                                    Open          High           Low  \
# Date
# 2024-08-05 00:00:00+09:00  35249.359375  35301.179688  31156.119141
#
#                                   Close     Volume  Dividends  Stock Splits
# Date
# 2024-08-05 00:00:00+09:00  31458.419922  285600000        0.0           0.0

# %%
tse = "https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls"
filename = wget.download(tse)
df_tickers = pd.read_excel(filename)[['コード', '銘柄名', '市場・商品区分']]
df_tickers
# Out:
# 100% [........................................................] 810496 / 810496
#        コード                                   銘柄名       市場・商品区分
# 0     1301                                    極洋    プライム（内国株式）
# 1     1305                ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）       ETF・ETN
# 2     1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信       ETF・ETN
# 3     1308                     上場インデックスファンドＴＯＰＩＸ       ETF・ETN
# 4     1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信       ETF・ETN
# ...    ...                                   ...           ...
# 4378  9991                                  ジェコス    プライム（内国株式）
# 4379  9993                                  ヤマザワ  スタンダード（内国株式）
# 4380  9994                                   やまや  スタンダード（内国株式）
# 4381  9996                                 サトー商会  スタンダード（内国株式）
# 4382  9997                                  ベルーナ    プライム（内国株式）
#
# [4383 rows x 3 columns]

# %%
sorted(list(set(df_tickers['市場・商品区分'])))
# Out:
# ['ETF・ETN',
#  'PRO Market',
#  'REIT・ベンチャーファンド・カントリーファンド・インフラファンド',
#  'グロース（内国株式）',
#  'グロース（外国株式）',
#  'スタンダード（内国株式）',
#  'スタンダード（外国株式）',
#  'プライム（内国株式）',
#  'プライム（外国株式）',
#  '出資証券']

# %%
list_market = [
    'ETF・ETN',
    'グロース（内国株式）',
    'スタンダード（内国株式）',
    'プライム（内国株式）',
]
df_target = df_tickers[df_tickers['市場・商品区分'].isin(list_market)]
df_target
# Out:
#        コード                                   銘柄名       市場・商品区分
# 0     1301                                    極洋    プライム（内国株式）
# 1     1305                ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）       ETF・ETN
# 2     1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信       ETF・ETN
# 3     1308                     上場インデックスファンドＴＯＰＩＸ       ETF・ETN
# 4     1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信       ETF・ETN
# ...    ...                                   ...           ...
# 4378  9991                                  ジェコス    プライム（内国株式）
# 4379  9993                                  ヤマザワ  スタンダード（内国株式）
# 4380  9994                                   やまや  スタンダード（内国株式）
# 4381  9996                                 サトー商会  スタンダード（内国株式）
# 4382  9997                                  ベルーナ    プライム（内国株式）
#
# [4198 rows x 3 columns]
