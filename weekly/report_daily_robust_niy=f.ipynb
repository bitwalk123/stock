# %% [markdown]
# # 日経平均先物 日足 メディアン統計

# %%
import sys
path_up = '..'
if not path_up in sys.path:
    sys.path.append(path_up)

# %%
import datetime

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pingouin as pg
import seaborn as sns
import yfinance as yf

from funcs.technical import calc_robust_bollinger

# %%
code = 'NIY=F'
symbol = '%s' % code
ticker = yf.Ticker(symbol)

# %%
# 日足で過去 2 年分のデータを取得
df0 = ticker.history(period='10y', interval='1d')
 
# ローソク足のチャートには、そのうち過去 1 年分のみ使用する
dt_last = df0.index[len(df0) - 1]
tdelta_1y =  datetime.timedelta(days=365)
df = df0[df0.index >= dt_last - tdelta_1y]
df
# Out:
#                               Open     High      Low    Close  Volume  \
# Date
# 2024-04-22 00:00:00-04:00  37665.0  37665.0  37665.0  37665.0       0
# 2024-04-23 00:00:00-04:00  37905.0  37905.0  37905.0  37905.0       0
# 2024-04-24 00:00:00-04:00  38215.0  38215.0  38215.0  38215.0       0
# 2024-04-25 00:00:00-04:00  37635.0  37635.0  37635.0  37635.0       0
# 2024-04-26 00:00:00-04:00  38355.0  38355.0  38355.0  38355.0       0
# ...                            ...      ...      ...      ...     ...
# 2025-04-14 00:00:00-04:00  34245.0  34245.0  34245.0  34245.0       0
# 2025-04-15 00:00:00-04:00  34470.0  34470.0  34470.0  34470.0       0
# 2025-04-16 00:00:00-04:00  34200.0  34200.0  33840.0  33840.0       1
# 2025-04-17 00:00:00-04:00  34455.0  34455.0  34455.0  34455.0       1
# 2025-04-21 00:00:00-04:00  34515.0  34630.0  33860.0  34145.0   15690
#
#                            Dividends  Stock Splits
# Date
# 2024-04-22 00:00:00-04:00        0.0           0.0
# 2024-04-23 00:00:00-04:00        0.0           0.0
# 2024-04-24 00:00:00-04:00        0.0           0.0
# 2024-04-25 00:00:00-04:00        0.0           0.0
# 2024-04-26 00:00:00-04:00        0.0           0.0
# ...                              ...           ...
# 2025-04-14 00:00:00-04:00        0.0           0.0
# 2025-04-15 00:00:00-04:00        0.0           0.0
# 2025-04-16 00:00:00-04:00        0.0           0.0
# 2025-04-17 00:00:00-04:00        0.0           0.0
# 2025-04-21 00:00:00-04:00        0.0           0.0
#
# [251 rows x 7 columns]

# %% [markdown]
# ## Moving Median

# %%
FONT_PATH = "../fonts/RictyDiminished-Regular.ttf"
fm.fontManager.addfont(FONT_PATH)

# FontPropertiesオブジェクト生成（名前の取得のため）
font_prop = fm.FontProperties(fname=FONT_PATH)
font_prop.get_name()

plt.rcParams['font.family'] = font_prop.get_name()
plt.rcParams['font.size'] = 16

fig = plt.figure(figsize=(12, 8))
ax = dict()
n = 2
gs = fig.add_gridspec(
    n, 1,
    wspace=0.0, hspace=0.0,
    height_ratios=[3 if i == 0 else 1 for i in range(n)]
)
for i, axis in enumerate(gs.subplots(sharex='col')):
    ax[i] = axis
    ax[i].grid()

mm005 = df0['Close'].rolling(5).median()
mm025 = df0['Close'].rolling(25).median()
mm075 = df0['Close'].rolling(75).median()
mm100 = df0['Close'].rolling(100).median()
mm200 = df0['Close'].rolling(200).median()
mm300 = df0['Close'].rolling(300).median()
mm600 = df0['Close'].rolling(600).median()
mm900 = df0['Close'].rolling(900).median()

apds  = [
    mpf.make_addplot(mm005[df.index], width=1, label='  5d median', ax=ax[0]),
    mpf.make_addplot(mm025[df.index], width=0.75, label=' 25d median', ax=ax[0]),
    mpf.make_addplot(mm075[df.index], width=0.75, label=' 75d median', ax=ax[0]),
    mpf.make_addplot(mm100[df.index], width=1, linestyle='dashed', label='100d median', ax=ax[0]),
    mpf.make_addplot(mm200[df.index], width=1, linestyle='dashed', label='200d median', ax=ax[0]),
    mpf.make_addplot(mm300[df.index], width=1, linestyle='dashed', label='300d median', ax=ax[0]),
    mpf.make_addplot(mm600[df.index], width=1.5, linestyle='dotted', label='600d median', ax=ax[0]),
    mpf.make_addplot(mm900[df.index], width=1.5, linestyle='dotted', label='900d median', ax=ax[0]),
]   

mpf.plot(df, type='candle', style='default', volume=ax[1], datetime_format='%y-%m-%d', addplot=apds, xrotation=0, ax=ax[0])

try:
    ax[0].set_title('Daily chart for %s (%s)\nwith moving median' % (ticker.info['shortName'], symbol))
except KeyError:
    ax[0].set_title('Daily chart for %s\nwith moving median' % (symbol, period))

ax[0].legend(loc='lower left', fontsize=9)

plt.tight_layout()
plt.savefig('report_daily_chart_median_%s.png' % code)
plt.show()

# %%
df.tail(2)
# Out:
#                               Open     High      Low    Close  Volume  \
# Date
# 2025-04-17 00:00:00-04:00  34455.0  34455.0  34455.0  34455.0       1
# 2025-04-21 00:00:00-04:00  34515.0  34630.0  33860.0  34145.0   15690
#
#                            Dividends  Stock Splits
# Date
# 2025-04-17 00:00:00-04:00        0.0           0.0
# 2025-04-21 00:00:00-04:00        0.0           0.0

# %%
df.tail(2)['Close']
# Out:
# Date
# 2025-04-17 00:00:00-04:00    34455.0
# 2025-04-21 00:00:00-04:00    34145.0
# Name: Close, dtype: float64

# %%
df.tail(2)['Close'].diff()
# Out:
# Date
# 2025-04-17 00:00:00-04:00      NaN
# 2025-04-21 00:00:00-04:00   -310.0
# Name: Close, dtype: float64

# %%
df['Close'].tail(1) - df['Open'].tail(1)
# Out:
# Date
# 2025-04-21 00:00:00-04:00   -370.0
# dtype: float64

# %%
df['Close'].rolling(9).median().tail()
# Out:
# Date
# 2025-04-14 00:00:00-04:00    33585.0
# 2025-04-15 00:00:00-04:00    33585.0
# 2025-04-16 00:00:00-04:00    33585.0
# 2025-04-17 00:00:00-04:00    33840.0
# 2025-04-21 00:00:00-04:00    34145.0
# Name: Close, dtype: float64

# %%
df['Close'].rolling(13).median().tail()
# Out:
# Date
# 2025-04-14 00:00:00-04:00    34245.0
# 2025-04-15 00:00:00-04:00    34245.0
# 2025-04-16 00:00:00-04:00    33845.0
# 2025-04-17 00:00:00-04:00    33845.0
# 2025-04-21 00:00:00-04:00    33845.0
# Name: Close, dtype: float64

# %%
df['Close'].rolling(26).median().tail()
# Out:
# Date
# 2025-04-14 00:00:00-04:00    36500.0
# 2025-04-15 00:00:00-04:00    36455.0
# 2025-04-16 00:00:00-04:00    36177.5
# 2025-04-17 00:00:00-04:00    35967.5
# 2025-04-21 00:00:00-04:00    35847.5
# Name: Close, dtype: float64

# %%
df['Close'].rolling(52).median().tail()
# Out:
# Date
# 2025-04-14 00:00:00-04:00    37700.0
# 2025-04-15 00:00:00-04:00    37660.0
# 2025-04-16 00:00:00-04:00    37625.0
# 2025-04-17 00:00:00-04:00    37607.5
# 2025-04-21 00:00:00-04:00    37587.5
# Name: Close, dtype: float64

# %% [markdown]
# ## Robust Bollinger's bands

# %%
FONT_PATH = "../fonts/RictyDiminished-Regular.ttf"
fm.fontManager.addfont(FONT_PATH)

# FontPropertiesオブジェクト生成（名前の取得のため）
font_prop = fm.FontProperties(fname=FONT_PATH)
font_prop.get_name()

plt.rcParams['font.family'] = font_prop.get_name()
plt.rcParams['font.size'] = 16

fig, ax = plt.subplots(figsize=(12, 8))

# Bollinger bands
period = 20
mv_median = df0['Close'].rolling(period).median()
mv_q1 = df0['Close'].rolling(period).quantile(.25)
mv_q3 = df0['Close'].rolling(period).quantile(.75)
mv_iqr = mv_q3 - mv_q1
mv_lower = mv_q1 - mv_iqr * 1.5
mv_upper = mv_q3 + mv_iqr * 1.5

apds  = [
    mpf.make_addplot(mv_upper[df.index], width=1.25, color='C1', linestyle='dotted', label='Upper bound', ax=ax),
    mpf.make_addplot(mv_q3[df.index], width=1, color='C2', linestyle='dashed', label='Q3 (75%)', ax=ax),
    mpf.make_addplot(mv_median[df.index], width=0.75, color='C3', label='Median', ax=ax),
    mpf.make_addplot(mv_q1[df.index], width=1, color='C4', linestyle='dashed', label='Q1 (25%)', ax=ax),
    mpf.make_addplot(mv_lower[df.index], width=1.25, color='C5', linestyle='dotted', label='Lower bound', ax=ax),
]   

mpf.plot(df, type='candle', style='default', addplot=apds, datetime_format='%y-%m-%d', xrotation=0, ax=ax)

ax.grid()
ax.legend(loc='best', fontsize=9)

try:
    ax.set_title('Daily chart for %s (%s)\nwith robust Bollinger bands (period=%ddays)' % (ticker.info['shortName'], symbol, period))
except KeyError:
    ax.set_title('Daily chart for %s\nwith robust Bollinger bands (period=%ddays)' % (symbol, period))

plt.tight_layout()
plt.savefig('report_daily_chart_bollinger_robust_%s.png' % code)
plt.show()

# %% [markdown]
# ## ヒストグラムと Q-Q プロット

# %%
plt.rcParams['font.size'] = 16

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(
    df['Close'],
    kde=True,
    ax=axes[0]
)

# ヒストグラム
axes[0].set_xlabel("Close")
axes[0].set_ylabel("count")
axes[0].grid(axis = 'y')
axes[0].set_title('Histogram', fontsize=16)

# Q-Q プロット
pg.qqplot(df['Close'], s=10,  ax=axes[1])
axes[1].set_title('Q-Q plot', fontsize=16)
axes[1].grid()

plt.suptitle('Daily data for %s (%s), n = %d' % (ticker.info['shortName'], symbol, len(df)), fontsize=18)
plt.subplots_adjust(wspace=0.3)
plt.savefig('report_daily_histogram_qqplot_%s.png' % code)
plt.show()

# %%
ticker.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 34465.0,
#  'open': 34515.0,
#  'dayLow': 33860.0,
#  'dayHigh': 34630.0,
#  'regularMarketPreviousClose': 34465.0,
#  'regularMarketOpen': 34515.0,
#  'regularMarketDayLow': 33860.0,
#  'regularMarketDayHigh': 34630.0,
#  'volume': 15690,
#  'regularMarketVolume': 15690,
#  'averageVolume': 9735,
#  'averageVolume10days': 0,
#  'averageDailyVolume10Day': 0,
#  'bid': 34140.0,
#  'ask': 34145.0,
#  'bidSize': 8,
#  'askSize': 9,
#  'expireDate': 1749772800,
#  'openInterest': 34504,
#  'fiftyTwoWeekLow': 32140.0,
#  'fiftyTwoWeekHigh': 42430.0,
#  'fiftyDayAverage': 36829.723,
#  'twoHundredDayAverage': 38152.91,
#  'currency': 'JPY',
#  'tradeable': False,
#  'quoteType': 'FUTURE',
#  'symbol': 'NIY=F',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Futures',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'NONE',
#  'contractSymbol': False,
#  'headSymbolAsString': 'NIY=F',
#  'marketState': 'REGULAR',
#  'corporateActions': [],
#  'regularMarketChange': -320.0,
#  'regularMarketDayRange': '33860.0 - 34630.0',
#  'fullExchangeName': 'CME',
#  'averageDailyVolume3Month': 9735,
#  'fiftyTwoWeekLowChange': 2005.0,
#  'fiftyTwoWeekLowChangePercent': 0.062383324,
#  'fiftyTwoWeekRange': '32140.0 - 42430.0',
#  'fiftyTwoWeekHighChange': -8285.0,
#  'fiftyTwoWeekHighChangePercent': -0.19526279,
#  'fiftyTwoWeekChangePercent': -8.522499,
#  'expireIsoDate': '2025-06-13T00:00:00Z',
#  'fiftyDayAverageChange': -2684.7227,
#  'fiftyDayAverageChangePercent': -0.07289554,
#  'twoHundredDayAverageChange': -4007.9102,
#  'twoHundredDayAverageChangePercent': -0.10504861,
#  'sourceInterval': 10,
#  'exchangeDataDelayedBy': 10,
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1077253200000,
#  'shortName': 'Nikkei/Yen Futures,Jun-2025',
#  'regularMarketChangePercent': -0.9284782,
#  'regularMarketPrice': 34145.0,
#  'regularMarketTime': 1745267633,
#  'underlyingSymbol': 'NIYM25.CME',
#  'underlyingExchangeSymbol': 'NIYM25.CME',
#  'exchange': 'CME',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us24_market',
#  'esgPopulated': False,
#  'trailingPegRatio': None}
