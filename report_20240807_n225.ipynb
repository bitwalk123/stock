# 2024-08-02 00:00:00+09:00  35909.699219  204300000        0.0           0.0
# 2024-08-05 00:00:00+09:00  31458.419922  285600000        0.0           0.0
# 2024-08-06 00:00:00+09:00  34675.460938  251200000        0.0           0.0
# 2024-08-07 00:00:00+09:00  35089.621094          0        0.0           0.0

# %%
fig, ax = plt.subplots(figsize=(6, 4))

mpf.plot(df, type='candle', style='yahoo', ax=ax)
ax.set_title('日経平均株価')

fig.subplots_adjust(left=0.05, right=0.85, bottom=0.15, top=0.9)
plt.savefig('report_20240807_n225_1.png')
plt.show()

# %%
ticker_n225.history_metadata
# Out:
# {'currency': 'JPY',
#  'symbol': '^N225',
#  'exchangeName': 'OSA',
#  'fullExchangeName': 'Osaka',
#  'instrumentType': 'INDEX',
#  'firstTradeDate': -157420800,
#  'regularMarketTime': 1722924902,
#  'hasPrePostMarketData': False,
#  'gmtoffset': 32400,
#  'timezone': 'JST',
#  'exchangeTimezoneName': 'Asia/Tokyo',
#  'regularMarketPrice': 34675.46,
#  'fiftyTwoWeekHigh': 34911.8,
#  'fiftyTwoWeekLow': 32077.33,
#  'regularMarketDayHigh': 34911.8,
#  'regularMarketDayLow': 32077.33,
#  'regularMarketVolume': 0,
#  'chartPreviousClose': 40912.37,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'JST',
#    'start': 1722988800,
#    'end': 1722988800,
#    'gmtoffset': 32400},
#   'regular': {'timezone': 'JST',
#    'start': 1722988800,
#    'end': 1723010400,
#    'gmtoffset': 32400},
#   'post': {'timezone': 'JST',
#    'start': 1723010400,
#    'end': 1723010400,
#    'gmtoffset': 32400}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
start = '2024-08-02'
end = '2024-08-07'
df_n225 = ticker_n225.history(start=start, end=end)
df_n225
# Out:
#                                    Open          High           Low  \
# Date
# 2024-08-02 00:00:00+09:00  37444.171875  37471.519531  35880.148438
# 2024-08-05 00:00:00+09:00  35249.359375  35301.179688  31156.119141
# 2024-08-06 00:00:00+09:00  32077.330078  34911.800781  32077.330078
#
#                                   Close     Volume  Dividends  Stock Splits
# Date
# 2024-08-02 00:00:00+09:00  35909.699219  204300000        0.0           0.0
# 2024-08-05 00:00:00+09:00  31458.419922  285600000        0.0           0.0
# 2024-08-06 00:00:00+09:00  34675.460938  251200000        0.0           0.0

# %%
float(df_n225['Close'].iloc[1] - df_n225['Close'].iloc[0])
# Out:
# -4451.279296875

# %%
tse = "https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls"
filename = wget.download(tse)
df_tickers = pd.read_excel(filename)[['コード', '銘柄名', '市場・商品区分']]
os.remove(filename)
df_tickers
# Out:
# 100% [........................................................] 810496 / 810496
#        コード                                   銘柄名       市場・商品区分
# 0     1301                                    極洋    プライム（内国株式）
# 1     1305                ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）       ETF・ETN
# 2     1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信       ETF・ETN
# 3     1308                     上場インデックスファンドＴＯＰＩＸ       ETF・ETN
# 4     1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信       ETF・ETN
# ...    ...                                   ...           ...
# 4378  9991                                  ジェコス    プライム（内国株式）
# 4379  9993                                  ヤマザワ  スタンダード（内国株式）
# 4380  9994                                   やまや  スタンダード（内国株式）
# 4381  9996                                 サトー商会  スタンダード（内国株式）
# 4382  9997                                  ベルーナ    プライム（内国株式）
#
# [4383 rows x 3 columns]

# %%
sorted(list(set(df_tickers['市場・商品区分'])))
# Out:
# ['ETF・ETN',
#  'PRO Market',
#  'REIT・ベンチャーファンド・カントリーファンド・インフラファンド',
#  'グロース（内国株式）',
#  'グロース（外国株式）',
#  'スタンダード（内国株式）',
#  'スタンダード（外国株式）',
#  'プライム（内国株式）',
#  'プライム（外国株式）',
#  '出資証券']

# %%
list_market = [
    'ETF・ETN',
    'グロース（内国株式）',
    'スタンダード（内国株式）',
    'プライム（内国株式）',
]
df_targets = df_tickers[df_tickers['市場・商品区分'].isin(list_market)]
df_targets
# Out:
#        コード                                   銘柄名       市場・商品区分
# 0     1301                                    極洋    プライム（内国株式）
# 1     1305                ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）       ETF・ETN
# 2     1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信       ETF・ETN
# 3     1308                     上場インデックスファンドＴＯＰＩＸ       ETF・ETN
# 4     1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信       ETF・ETN
# ...    ...                                   ...           ...
# 4378  9991                                  ジェコス    プライム（内国株式）
# 4379  9993                                  ヤマザワ  スタンダード（内国株式）
# 4380  9994                                   やまや  スタンダード（内国株式）
# 4381  9996                                 サトー商会  スタンダード（内国株式）
# 4382  9997                                  ベルーナ    プライム（内国株式）
#
# [4198 rows x 3 columns]

# %%
df_targets = pd.concat([df_targets['コード'].astype(str), df_targets['銘柄名'], df_targets['市場・商品区分']], axis=1)

# %%
#start = '2024-08-02'
#end = '2024-08-07'
dict_close_1 = dict()
dict_close_2 = dict()
dict_close_3 = dict()
dict_recovery = dict()

for code in df_targets['コード']:
    code2 = '%s.T' % code
    ticker = yf.Ticker(code2)
    df = ticker.history(start=start, end=end)
    if len(df) != 3:
        continue

    price_close_1 = float(df['Close'].iloc[0])
    price_close_2 = float(df['Close'].iloc[1])
    drop = price_close_1 - price_close_2
    mean = (price_close_1 + price_close_2) / 2
    if drop / mean <= 0.05:
        continue

    price_close_3 = float(df['Close'].iloc[2])
    up = price_close_3 - price_close_2

    recovery = up / drop
    dict_close_1[code] = price_close_1
    dict_close_2[code] = price_close_2
    dict_close_3[code] = price_close_3
    dict_recovery[code] = recovery
# Out:
# 162A.T: Period '1mo' is invalid, must be one of ['1d', '5d']
# 163A.T: Period '1mo' is invalid, must be one of ['1d', '5d']
# $2031.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2032.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2031.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2032.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2033.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2034.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2033.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2034.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2036.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2037.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2036.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2037.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2038.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2038.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2040.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2041.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2040.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2041.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2042.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2043.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2042.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2043.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2044.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2045.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2044.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2045.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2046.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2047.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2046.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2047.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2048.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2048.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2065.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2066.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2065.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2066.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2067.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2068.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2067.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2068.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2069.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# $2069.T: possibly delisted; No price data found  (1d 2024-08-02 -> 2024-08-07)
# 2073.T: Period '1mo' is invalid, must be one of ['1d', '5d']
# 21649.T: Period '1mo' is invalid, must be one of ['1d', '5d']
# $94345.T: possibly delisted; No timezone found

# %%
df_close_1 = pd.DataFrame(
    dict_close_1,
    index=['close1']
).T
df_close_2 = pd.DataFrame(
    dict_close_2,
    index=['close2']
).T
df_close_3 = pd.DataFrame(
    dict_close_3,
    index=['close3']
).T
df_recovery = pd.DataFrame(
    dict_recovery,
    index=['ratio']
).T

df_result = pd.concat([df_close_1, df_close_2, df_close_3, df_recovery], axis=1)
df_result
# Out:
#       close1  close2  close3     ratio
# 1301  3760.0  3450.0  3665.0  0.693548
# 1305  2656.0  2350.0  2520.0  0.555556
# 1306  2634.5  2349.5  2491.5  0.498246
# 1308  2600.0  2290.0  2461.0  0.551613
# 130A   787.0   637.0   680.0  0.286667
# ...      ...     ...     ...       ...
# 9987  5053.0  4766.0  5190.0  1.477352
# 9989  3977.0  3751.0  3917.0  0.734513
# 9991   922.0   772.0   831.0  0.393333
# 9994  3030.0  2849.0  2910.0  0.337017
# 9997   699.0   627.0   685.0  0.805556
#
# [3652 rows x 4 columns]

# %%
df_result_top = df_result.sort_values('ratio', ascending=False).head(30)

# %%
df_result_top
# Out:
#        close1   close2   close3     ratio
# 8136   2875.0   2701.0   3185.0  2.781609
# 3103    266.0    231.0    311.0  2.285714
# 7678   3375.0   3190.0   3600.0  2.216216
# 6088   1274.0   1135.0   1435.0  2.158273
# 7874   1071.0   1013.0   1137.0  2.137931
# 5892   1314.0   1159.0   1459.0  1.935484
# 8114   3730.0   3365.0   4065.0  1.917808
# 7859    339.0    304.0    371.0  1.914286
# 4958   2911.0   2648.0   3150.0  1.908745
# 2676   3635.0   3455.0   3795.0  1.888889
# 7741  17585.0  16065.0  18720.0  1.746711
# 8801   1371.0   1247.5   1456.5  1.692308
# 3542    704.0    660.0    734.0  1.681818
# 6532   4120.0   3846.0   4303.0  1.667883
# 3097   3240.0   2990.0   3405.0  1.660000
# 8129   4096.0   3800.0   4286.0  1.641892
# 5393   4355.0   3925.0   4625.0  1.627907
# 3276   1139.0   1077.0   1176.0  1.596774
# 8194   3455.0   3230.0   3585.0  1.577778
# 1980   2734.0   2417.0   2917.0  1.577287
# 7105   1168.0   1009.0   1257.0  1.559748
# 3825    161.0    141.0    172.0  1.550000
# 7630   1036.0    983.0   1065.0  1.547170
# 2371   1884.5   1624.0   2024.0  1.535509
# 4819   2606.0   2375.0   2728.0  1.528139
# 3719    199.0    174.0    212.0  1.520000
# 7564   4190.0   3965.0   4305.0  1.511111
# 3197   1943.5   1836.5   1997.5  1.504673
# 6151   2140.0   1994.0   2213.0  1.500000
# 2784   2143.5   2003.5   2212.5  1.492857

# %%
#df_result_top.index = df_result_top.index.map(str)
#df_result_top.index.map(str)
#df_result_top.index
df_result_top_asc = df_result_top.sort_values('ratio', ascending=True)

# %%
df_result_top_asc['cname'] = ['%s (%s)' % (df_targets.loc[df_targets['コード'] == code, '銘柄名'].iloc[0], code) for code in df_result_top_asc.index]

# %%
fig, ax = plt.subplots(figsize=(6, 7))

ax.barh(df_result_top_asc['cname'], df_result_top_asc['ratio'])

ax.set_title('Aug 05 の急落と翌日のリバウンド')
ax.set_xlabel('リバウンド比率')
ax.grid(axis = 'y')

fig.subplots_adjust(left=0.5, right=0.995, bottom=0.1, top=0.95)
plt.savefig('report_20240807_n225_2.png')
plt.show()
