# %% [markdown]
# # 2024-08-05 と 2025-04-07

# %% [markdown]
# Reference: https://ja.wikipedia.org/wiki/2024%E5%B9%B4%E3%81%AE%E6%A0%AA%E4%BE%A1%E5%A4%A7%E6%9A%B4%E8%90%BD
#
# 2024年8月2日、アメリカ合衆国労働省の雇用率の大幅な低下を示す雇用統計を受けて金融市場は下落し、景気後退の懸念が高まりました。
#
# この株価大暴落は、以下の影響を受けました。
#
# - 日本銀行の利上げ決定に伴う日本株の下落
# - 企業利益の減少を投資家が懸念したことによる日本円の円高の進行
# - アメリカ合衆国のテクノロジー株が過大評価されているとの認識

# %%
import datetime

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import yfinance as yf

# %%
def chart_candle(df):
    FONT_PATH = "../fonts/RictyDiminished-Regular.ttf"
    fm.fontManager.addfont(FONT_PATH)
    
    # FontPropertiesオブジェクト生成（名前の取得のため）
    font_prop = fm.FontProperties(fname=FONT_PATH)
    font_prop.get_name()
    
    plt.rcParams['font.family'] = font_prop.get_name()
    plt.rcParams['font.size'] = 16
    
    fig, ax = plt.subplots(figsize=(12, 6))
    
    mpf.plot(df, type='candle', style='default', datetime_format='%y-%m-%d', xrotation=0, ax=ax)
    ax.grid()

    return ax

# %%
code = 'SOX'
symbol = '^%s' % code
ticker = yf.Ticker(symbol)

# %%
# 2024-08-05
df1 = ticker.history(start='2024-07-22', end='2024-08-10', interval='1d')
df1
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2024-07-22 00:00:00-04:00  5382.490234  5481.970215  5344.270020  5477.830078
# 2024-07-23 00:00:00-04:00  5407.609863  5453.600098  5385.950195  5397.899902
# 2024-07-24 00:00:00-04:00  5320.100098  5330.910156  5098.430176  5105.649902
# 2024-07-25 00:00:00-04:00  5052.299805  5168.089844  4906.729980  5005.359863
# 2024-07-26 00:00:00-04:00  5110.629883  5147.939941  5056.209961  5103.129883
# 2024-07-29 00:00:00-04:00  5156.000000  5226.379883  5074.299805  5087.620117
# 2024-07-30 00:00:00-04:00  5108.009766  5119.350098  4874.609863  4890.149902
# 2024-07-31 00:00:00-04:00  5127.620117  5240.580078  5088.439941  5233.180176
# 2024-08-01 00:00:00-04:00  5143.839844  5201.290039  4801.049805  4859.589844
# 2024-08-02 00:00:00-04:00  4644.459961  4698.879883  4540.680176  4607.759766
# 2024-08-05 00:00:00-04:00  4330.259766  4635.129883  4290.350098  4519.450195
# 2024-08-06 00:00:00-04:00  4558.700195  4683.060059  4493.669922  4567.569824
# 2024-08-07 00:00:00-04:00  4709.620117  4738.939941  4418.569824  4426.270020
# 2024-08-08 00:00:00-04:00  4552.160156  4736.720215  4472.350098  4730.009766
# 2024-08-09 00:00:00-04:00  4702.970215  4746.270020  4643.850098  4709.450195
#
#                            Volume  Dividends  Stock Splits
# Date
# 2024-07-22 00:00:00-04:00       0        0.0           0.0
# 2024-07-23 00:00:00-04:00       0        0.0           0.0
# 2024-07-24 00:00:00-04:00       0        0.0           0.0
# 2024-07-25 00:00:00-04:00       0        0.0           0.0
# 2024-07-26 00:00:00-04:00       0        0.0           0.0
# 2024-07-29 00:00:00-04:00       0        0.0           0.0
# 2024-07-30 00:00:00-04:00       0        0.0           0.0
# 2024-07-31 00:00:00-04:00       0        0.0           0.0
# 2024-08-01 00:00:00-04:00       0        0.0           0.0
# 2024-08-02 00:00:00-04:00       0        0.0           0.0
# 2024-08-05 00:00:00-04:00       0        0.0           0.0
# 2024-08-06 00:00:00-04:00       0        0.0           0.0
# 2024-08-07 00:00:00-04:00       0        0.0           0.0
# 2024-08-08 00:00:00-04:00       0        0.0           0.0
# 2024-08-09 00:00:00-04:00       0        0.0           0.0

# %%
ax = chart_candle(df1)
ax.set_title('Daily chart for %s (%s)\n2024年8月5日の暴落時' %(ticker.info['longName'], symbol))

plt.tight_layout()
plt.savefig('report_crash_2024-08-05_%s.png' % code)
plt.show()

# %%
# 2025-04-07
df2 = ticker.history(start='2025-03-24', end='2025-04-12', interval='1d')

for day_str in ['2025-04-04', '2025-04-07', '2025-04-08', '2025-04-09', '2025-04-10', '2025-04-11']:
    d = pd.to_datetime('%s 00:00:00-04:00' % day_str)
    df2.loc[d, 'Dividends'] = 0

print(df2)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2025-03-24 00:00:00-04:00  4662.899902  4722.479980  4657.330078  4694.220215
# 2025-03-25 00:00:00-04:00  4679.879883  4693.200195  4648.799805  4661.339844
# 2025-03-26 00:00:00-04:00  4639.919922  4649.540039  4467.709961  4508.740234
# 2025-03-27 00:00:00-04:00  4452.520020  4476.370117  4394.799805  4415.250000
# 2025-03-28 00:00:00-04:00  4387.839844  4411.660156  4259.930176  4284.910156
# 2025-03-31 00:00:00-04:00  4193.500000  4277.189941  4129.609863  4270.430176
# 2025-04-01 00:00:00-04:00  4253.549805  4285.959961  4179.450195  4282.459961
# 2025-04-02 00:00:00-04:00  4216.240234  4374.509766  4206.660156  4320.750000
# 2025-04-03 00:00:00-04:00  4115.129883  4131.819824  3889.620117  3893.689941
# 2025-04-04 00:00:00-04:00          NaN          NaN          NaN          NaN
# 2025-04-07 00:00:00-04:00          NaN          NaN          NaN          NaN
# 2025-04-08 00:00:00-04:00          NaN          NaN          NaN          NaN
# 2025-04-09 00:00:00-04:00          NaN          NaN          NaN          NaN
# 2025-04-10 00:00:00-04:00          NaN          NaN          NaN          NaN
# 2025-04-11 00:00:00-04:00          NaN          NaN          NaN          NaN
#
#                            Volume  Dividends  Stock Splits
# Date
# 2025-03-24 00:00:00-04:00     0.0        0.0           0.0
# 2025-03-25 00:00:00-04:00     0.0        0.0           0.0
# 2025-03-26 00:00:00-04:00     0.0        0.0           0.0
# 2025-03-27 00:00:00-04:00     0.0        0.0           0.0
# 2025-03-28 00:00:00-04:00     0.0        0.0           0.0
# 2025-03-31 00:00:00-04:00     0.0        0.0           0.0
# 2025-04-01 00:00:00-04:00     0.0        0.0           0.0
# 2025-04-02 00:00:00-04:00     0.0        0.0           0.0
# 2025-04-03 00:00:00-04:00     0.0        0.0           0.0
# 2025-04-04 00:00:00-04:00     NaN        0.0           NaN
# 2025-04-07 00:00:00-04:00     NaN        0.0           NaN
# 2025-04-08 00:00:00-04:00     NaN        0.0           NaN
# 2025-04-09 00:00:00-04:00     NaN        0.0           NaN
# 2025-04-10 00:00:00-04:00     NaN        0.0           NaN
# 2025-04-11 00:00:00-04:00     NaN        0.0           NaN

# %%
ax = chart_candle(df2)
ax.set_title('Daily chart for %s (%s)\n2025年4月2日にトランプ関税発動' %(ticker.info['longName'], symbol))

plt.tight_layout()
plt.savefig('report_crash_2025-04-07_%s.png' % code)
plt.show()
