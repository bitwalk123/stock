# %%
import matplotlib.pyplot as plt
import mplfinance as mpf
import yfinance as yf

symbol = '7751.T'
#symbol = 'USDJPY=X'
ticker = yf.Ticker(symbol)
df = ticker.history(period='10y', interval='1mo')
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2015-04-01 00:00:00+09:00  2851.528447  3069.992320  2817.372330  2896.844482
# 2015-05-01 00:00:00+09:00  2896.844656  2962.451457  2849.499541  2902.931885
# 2015-06-01 00:00:00+09:00  2921.530994  2931.338194  2638.474918  2693.598145
# 2015-07-01 00:00:00+09:00  2753.472475  2792.379864  2600.597425  2735.223877
# 2015-08-01 00:00:00+09:00  2737.289910  2820.613704  2425.686468  2552.738037
# ...                                ...          ...          ...          ...
# 2024-11-01 00:00:00+09:00  4848.243450  5080.848746  4795.020204  4797.977051
# 2024-12-01 00:00:00+09:00  4829.516994  5198.137271  4796.006060  5086.762695
# 2025-01-01 00:00:00+09:00  5161.000000  5161.000000  4825.000000  5018.000000
# 2025-02-01 00:00:00+09:00  4925.000000  5233.000000  4752.000000  5063.000000
# 2025-03-01 00:00:00+09:00  5115.000000  5195.000000  5101.000000  5130.000000
#
#                               Volume  Dividends  Stock Splits
# Date
# 2015-04-01 00:00:00+09:00   98057200        0.0           0.0
# 2015-05-01 00:00:00+09:00   76466700        0.0           0.0
# 2015-06-01 00:00:00+09:00  104656200       75.0           0.0
# 2015-07-01 00:00:00+09:00   97985100        0.0           0.0
# 2015-08-01 00:00:00+09:00   89659300        0.0           0.0
# ...                              ...        ...           ...
# 2024-11-01 00:00:00+09:00   45345700        0.0           0.0
# 2024-12-01 00:00:00+09:00   49680000       75.0           0.0
# 2025-01-01 00:00:00+09:00   51886200        0.0           0.0
# 2025-02-01 00:00:00+09:00   66081500        0.0           0.0
# 2025-03-01 00:00:00+09:00    5938400        0.0           0.0
#
# [120 rows x 7 columns]

# %%
fig = plt.figure(figsize=(12, 6))
#ax = fig.add_axes(111)
ax = fig.add_subplot(111)

mpf.plot(
    df, type='candle', style='default',
    mav=(6, 12, 36),
    volume=False,
    datetime_format='%Y-%m',
    xrotation=0,
    ax=ax,
)
ax.set_title('Monthly chart for %s (%s)\nmav=(6, 12, 36)' %(ticker.info['longName'], symbol))
ax.grid()

plt.tight_layout()
plt.savefig('monthly_chart_7751.png')
plt.show()

# %%
df.tail(2)
# Out:
#                                    Open          High           Low  \
# Date
# 2024-08-01 00:00:00+09:00  38781.558594  38781.558594  31156.119141
# 2024-09-01 00:00:00+09:00  39025.308594  39080.640625  36235.609375
#
#                                  Close      Volume  Dividends  Stock Splits
# Date
# 2024-08-01 00:00:00+09:00  38647.75000  3034000000        0.0           0.0
# 2024-09-01 00:00:00+09:00  36391.46875   545700000        0.0           0.0
