# %%
import matplotlib.pyplot as plt
import mplfinance as mpf
import yfinance as yf

symbol = '7751.T'
#symbol = 'USDJPY=X'
ticker = yf.Ticker(symbol)
df = ticker.history(period='10y', interval='1mo')
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2014-12-01 00:00:00+09:00  2570.418618  2717.194122  2507.274923  2579.822998
# 2015-01-01 00:00:00+09:00  2635.465258  2710.607412  2514.002596  2566.842285
# 2015-02-01 00:00:00+09:00  2539.049668  2674.236907  2507.139990  2668.747070
# 2015-03-01 00:00:00+09:00  2676.295601  2957.306639  2649.532644  2915.103516
# 2015-04-01 00:00:00+09:00  2893.143955  3114.796113  2858.489361  2939.121338
# ...                                ...          ...          ...          ...
# 2024-07-01 00:00:00+09:00  4375.000000  4778.000000  4279.000000  4742.000000
# 2024-08-01 00:00:00+09:00  4602.000000  5091.000000  3704.000000  5017.000000
# 2024-09-01 00:00:00+09:00  5090.000000  5121.000000  4643.000000  4703.000000
# 2024-10-01 00:00:00+09:00  4718.000000  5162.000000  4692.000000  5004.000000
# 2024-11-01 00:00:00+09:00  4919.000000  5155.000000  4868.000000  5005.000000
#
#                               Volume  Dividends  Stock Splits
# Date
# 2014-12-01 00:00:00+09:00  113318600       85.0           0.0
# 2015-01-01 00:00:00+09:00   80666000        0.0           0.0
# 2015-02-01 00:00:00+09:00   77314900        0.0           0.0
# 2015-03-01 00:00:00+09:00  104306700        0.0           0.0
# 2015-04-01 00:00:00+09:00   98057200        0.0           0.0
# ...                              ...        ...           ...
# 2024-07-01 00:00:00+09:00   81408200        0.0           0.0
# 2024-08-01 00:00:00+09:00  120487200        0.0           0.0
# 2024-09-01 00:00:00+09:00   77207600        0.0           0.0
# 2024-10-01 00:00:00+09:00   66655700        0.0           0.0
# 2024-11-01 00:00:00+09:00   16919800        0.0           0.0
#
# [120 rows x 7 columns]

# %%
fig = plt.figure(figsize=(12, 6))
#ax = fig.add_axes(111)
ax = fig.add_subplot(111)

mpf.plot(
    df, type='candle', style='default',
    mav=(6, 12, 36),
    volume=False,
    datetime_format='%Y-%m',
    xrotation=0,
    ax=ax,
)
ax.set_title('Monthly chart for %s (%s)\nmav=(6, 12, 36)' %(ticker.info['longName'], symbol))
ax.grid()

plt.tight_layout()
plt.savefig('monthly_chart_7751.png')
plt.show()

# %%
df.tail(2)
# Out:
#                                    Open          High           Low  \
# Date
# 2024-08-01 00:00:00+09:00  38781.558594  38781.558594  31156.119141
# 2024-09-01 00:00:00+09:00  39025.308594  39080.640625  36235.609375
#
#                                  Close      Volume  Dividends  Stock Splits
# Date
# 2024-08-01 00:00:00+09:00  38647.75000  3034000000        0.0           0.0
# 2024-09-01 00:00:00+09:00  36391.46875   545700000        0.0           0.0
