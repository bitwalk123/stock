# %%
import matplotlib.pyplot as plt
import mplfinance as mpf
import yfinance as yf

symbol = '7751.T'
#symbol = 'USDJPY=X'
ticker = yf.Ticker(symbol)
df = ticker.history(period='10y', interval='1mo')
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2014-10-01 00:00:00+09:00  2410.880026  2415.246346  2130.763846  2276.531738
# 2014-11-01 00:00:00+09:00  2276.531883  2554.968727  2276.531883  2553.625244
# 2014-12-01 00:00:00+09:00  2570.418131  2717.193608  2507.274448  2579.822510
# 2015-01-01 00:00:00+09:00  2635.464506  2710.606639  2514.001879  2566.841553
# 2015-02-01 00:00:00+09:00  2539.049901  2674.237152  2507.140219  2668.747314
# ...                                ...          ...          ...          ...
# 2024-05-01 00:00:00+09:00  4204.126475  4493.184750  4152.017330  4475.487305
# 2024-06-01 00:00:00+09:00  4493.184776  4623.949234  4233.622242  4280.815430
# 2024-07-01 00:00:00+09:00  4375.000000  4778.000000  4279.000000  4742.000000
# 2024-08-01 00:00:00+09:00  4602.000000  5091.000000  3704.000000  5017.000000
# 2024-09-01 00:00:00+09:00  5090.000000  5121.000000  4643.000000  4750.000000
#
#                               Volume  Dividends  Stock Splits
# Date
# 2014-10-01 00:00:00+09:00  128816700        0.0           0.0
# 2014-11-01 00:00:00+09:00  121880900        0.0           0.0
# 2014-12-01 00:00:00+09:00  113318600       85.0           0.0
# 2015-01-01 00:00:00+09:00   80666000        0.0           0.0
# 2015-02-01 00:00:00+09:00   77314900        0.0           0.0
# ...                              ...        ...           ...
# 2024-05-01 00:00:00+09:00   71022700        0.0           0.0
# 2024-06-01 00:00:00+09:00   64730800       75.0           0.0
# 2024-07-01 00:00:00+09:00   81408200        0.0           0.0
# 2024-08-01 00:00:00+09:00  120487200        0.0           0.0
# 2024-09-01 00:00:00+09:00   53495500        0.0           0.0
#
# [120 rows x 7 columns]

# %%
fig = plt.figure(figsize=(12, 6))
#ax = fig.add_axes(111)
ax = fig.add_subplot(111)

mpf.plot(
    df, type='candle', style='yahoo',
    mav=(6, 12, 36),
    volume=False,
    datetime_format='%Y-%m',
    xrotation=0,
    ax=ax,
)
ax.set_title('Monthly chart for %s (%s)\nmav=(6, 12, 36)' %(ticker.info['longName'], symbol))
ax.grid()

plt.tight_layout()
plt.savefig('monthly_chart_7751.png')
plt.show()

# %%
df.tail(2)
# Out:
#                                    Open          High           Low  \
# Date
# 2024-08-01 00:00:00+09:00  38781.558594  38781.558594  31156.119141
# 2024-09-01 00:00:00+09:00  39025.308594  39080.640625  36235.609375
#
#                                  Close      Volume  Dividends  Stock Splits
# Date
# 2024-08-01 00:00:00+09:00  38647.75000  3034000000        0.0           0.0
# 2024-09-01 00:00:00+09:00  36391.46875   545700000        0.0           0.0
