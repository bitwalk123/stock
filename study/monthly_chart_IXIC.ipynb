# %%
import matplotlib.pyplot as plt
import mplfinance as mpf
import pandas as pd
import yfinance as yf

#symbol = '^IXIC'
symbol = '^GSPC'
ticker = yf.Ticker(symbol)
df = ticker.history(period='max', interval='1mo')
#df = ticker.history(start='1993-01-01', end='1998-01-01', interval='1mo')
#df = ticker.history(start='2019-11-01', end='2024-11-01', interval='1mo')
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1985-01-01 00:00:00-05:00   167.199997   180.270004   163.360001   179.630005
# 1985-02-01 00:00:00-05:00   179.630005   183.949997   177.750000   181.179993
# 1985-03-01 00:00:00-05:00   181.179993   183.889999   176.529999   180.660004
# 1985-04-01 00:00:00-05:00   180.660004   183.610001   177.860001   179.830002
# 1985-05-01 00:00:00-04:00   179.830002   189.979996   178.350006   189.550003
# ...                                ...          ...          ...          ...
# 2024-06-01 00:00:00-04:00  5297.149902  5523.640137  5234.319824  5460.479980
# 2024-07-01 00:00:00-04:00  5471.080078  5669.669922  5390.950195  5522.299805
# 2024-08-01 00:00:00-04:00  5537.839844  5651.620117  5119.259766  5648.399902
# 2024-09-01 00:00:00-04:00  5623.890137  5767.370117  5402.620117  5762.479980
# 2024-10-01 00:00:00-04:00  5757.729980  5878.459961  5674.000000  5808.120117
#
# ...

# %%
ticker.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 5809.86,
#  'open': 5826.75,
#  'dayLow': 5799.98,
#  'dayHigh': 5862.82,
#  'regularMarketPreviousClose': 5809.86,
#  'regularMarketOpen': 5826.75,
#  'regularMarketDayLow': 5799.98,
#  'regularMarketDayHigh': 5862.82,
#  'volume': 2270596000,
#  'regularMarketVolume': 2270596000,
#  'averageVolume': 3733312812,
#  'averageVolume10days': 3453515000,
#  'averageDailyVolume10Day': 3453515000,
#  'bid': 5771.44,
#  'ask': 5854.58,
#  'fiftyTwoWeekLow': 4132.94,
#  'fiftyTwoWeekHigh': 5878.46,
#  'fiftyDayAverage': 5682.678,
#  'twoHundredDayAverage': 5333.876,
#  'currency': 'USD',
#  'exchange': 'SNP',
#  'quoteType': 'INDEX',
#  'symbol': '^GSPC',
#  'underlyingSymbol': '^GSPC',
#  'shortName': 'S&P 500',
#  'longName': 'S&P 500',
#  'firstTradeDateEpochUtc': -1325583000,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '8ffd55d1-3d1d-3733-a480-56768bc708e6',
# ...

# %%
mswin = dict(
    vlines=[
        '1985-11-20', # Windows 1
        '1987-12-09', # Windows 2
        '1990-05-22', # Windows 3
        '1993-07-27', # Windows NT
        '1995-08-24', # Windows 95
        '1998-06-25', # Windows 98
        '1999-12-15', # Windows 2000
        '2000-09-14', # Windows Me
        '2001-08-24', # Windows XP
        '2006-11-30', # Windows Vista
        '2009-09-01', # Windows 7
        '2012-08-16', # Windows 8
        '2015-07-29', # Windows 10
        '2021-10-05', # Windows 11
    ],
    linewidths=0.5,
    colors=['C0', 'C0', 'C0', 'C0', 'C1', 'C0', 'C0', 'C0', 'C1', 'C0', 'C1', 'C0', 'C1', 'C1']
)

# %%
fig = plt.figure(figsize=(10, 6))
#ax = fig.add_axes(111)
ax = fig.add_subplot(111)

mpf.plot(
    df, type='candle', style='yahoo',
    volume=False,
    vlines=mswin,
    datetime_format='%Y-%m-%d',
    xrotation=0,
    ax=ax,
)
ax.set_title('Monthly chart for %s' % ticker.info['longName'])
ax.grid()

plt.tight_layout()
plt.savefig('monthly_chart.png')
plt.show()

# %%
ax.get_xticks()
# Out:
# array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.])
